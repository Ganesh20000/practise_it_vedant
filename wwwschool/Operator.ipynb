# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ## Operator

# %% [markdown]
# #### arithmetice

# %%
x=44
y=78
print(x+y)
# Out:
# 122

# %%
print(x-y)
# Out:
# -34

# %%
print(x%y)
# Out:
# 44

# %% [markdown]
# #### Assignment operator

# %%
x+=7
print(x)
# Out:
# 51

# %%
x=y
print(y)
# Out:
# 78

# %%
x/=78
print(x)
# Out:
# 0.01282051282051282

# %% [markdown]
# #### Comparision operator

# %%
print(x<y)
print(y>=x)
print(x!=y)
print(x==y)
# Out:
# True
# True
# True
# False

# %% [markdown]
# #### Logical operator

# %%
print(x>y and x<y)

print(x!=y or x<=y)
# Out:
# False
# True

# %%
x=['a','b','c','e','d','o','p']


print('a' is x)


print('z' is not x)
# Out:
# False
# True
# <>:4: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# <>:7: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
# <>:4: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# <>:7: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
# C:\Users\karli\AppData\Local\Temp\ipykernel_17740\4081238728.py:4: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   print('a' is x)
# C:\Users\karli\AppData\Local\Temp\ipykernel_17740\4081238728.py:7: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
#   print('z' is not x)

# %% [markdown]
# #### Membership operator

# %%
x=['a','b','c','z','e','i','o']


print('e' in x)


print('e'  not in x)
# Out:
# True
# False

# %% [markdown]
# #### operator precendence

# %%
print((6*5)+(6+5))
# Out:
# 41

# %%
print(200+4*12)
# Out:
# 248

# %%
print((47+2)-(7*5))
# Out:
# 14
