# %% [markdown]
# Built-in Data Types
# In programming, data type is an important concept.
#
# Variables can store data of different types, and different types can do different things.
#
# Python has the following data types built-in by default, in these categories:
#
# <!-- Text Type:	str,
# Numeric Types:	int, float, complex,
# Sequence Types:	list, tuple, range,
# Mapping Type:	dict,
# Set Types:	set, frozenset,
# Boolean Type:	bool,
# Binary Types:	bytes, bytearray, memoryview,
# None Type:	NoneType, -->

# %% [markdown]
# ### NUMBERS

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ### string

# %%
print("ganesh karli")
# Out:
# ganesh karli

# %%
print("j")
# Out:
# j

# %% [markdown]
# #Slicing string

# %%
X='Python is tHe bEsTt sNake'

print(X[0:])
# Out:
# Python is tHe bEsTt sNake

# %% [markdown]
# ### modify string

# %%
print(X.upper())
# Out:
# PYTHON IS THE BESTT SNAKE

# %%
print(X.lower())
# Out:
# python is the bestt snake

# %%
print(X.title())
# Out:
# Python Is The Bestt Snake

# %%
print(X.strip())
# Out:
# Python is tHe bEsTt sNake

# %%
print(X.lstrip())
# Out:
# Python is tHe bEsTt sNake

# %%
print(X.startswith('P'))
# Out:
# True

# %%
print(X.replace("s","J"))
# Out:
# Python iJ tHe bEJTt JNake

# %%
a = "Hello"
b = "World"

print(a+b)
# Out:
# HelloWorld

# %% [markdown]
# ## Format string

# %%
study="B.E"

cgpa=8.8

name="alice"


print(f"the {name} is best student , he studied {study} and score in final {cgpa}")
# Out:
# the alice is best student , he studied B.E and score in final 8.8

# %% [markdown]
# ### Boolean

# %%
print(5>=5)
# Out:
# True

# %%
X=6

print(X>=7)
# Out:
# False
