# %%
data = [('Mon',32),('Tue',35),('Wed',33),('Thu',35),('Fri',30)]

large=data[0][1]

for day,values in data:
    if values>large:
        large=values
       
days=[]
for day,values in data:
    if values==large:
        # print(values)
        days.append(day)
        



print(large)
print(days)
# Out:
# 35
# ['Tue', 'Thu']

# %%
data = [('Mon',32),('Tue',35),('Wed',33),('Thu',35),('Fri',30)]

large = data[0][1]

# find largest temperature
for day,values in data:
    if values > large:
        large = values

days = []

# find all days with largest temperature
for day,values in data:
    if values == large:
        days.append(day)

print(large)
print(days)
# Out:
# 35
# ['Tue', 'Thu']

# %%
data = "Good morning"
# Expected Output:



e=data.split(" ")
# print(e)
c=0
for i in e:
    if len(i)>5:
        c+=1

print(c)
# Out:
# 1

# %%
d="python"


j=d[::-1]

if d==j:
    print("palindrom")
else:
    print("not")
# Out:
# not

# %%
d="Python programming is fun" 


o=d.split()

print(o)


large=o[0]
print(large)
for i in  o:
    if len(i)>len(large):
        large=i



print(large)
# Out:
# ['Python', 'programming', 'is', 'fun']
# Python
# programming

# %%
d= {'a': 10, 'b': 20, 'c': 15}


for i,k in d.items():
    print(k)
# Out:
# 10
# 20
# 15

# %%
d= {'a': 10, 'b': 20, 'c': 15}

# l=d[1][1]

# print(l)
x=list(d.values())
d2=x[0]
print(d)
for i ,j in d.items():
    if j>d2:
        d2=j


# print(j)
    
p=[]

for i ,k in d.items():
    if k==d2:
        p.append(i)

print(p)
# Out:
# {'a': 10, 'b': 20, 'c': 15}
# ['b']

# %% [markdown]
# ### recuerssion power on problem

# %%
def rec(n,p):
    if p==0:
        return 1
    
    return n*rec(n,p-1)
    

print(rec(2,3))
# Out:
# 8
