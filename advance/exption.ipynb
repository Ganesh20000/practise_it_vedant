# %%
class bank:

    def __init__(self,balance):
        self.balance=balance


    def withdraw(self,amount):
        if amount <0:
            raise Exception("amount cant be -ve")
        if self.balance<amount:
            raise Exception("amount cant be greater than balance")
        self.balance=self.balance-amount


new=bank(10000)
try:
    new.withdraw(780)
    
except Exception as e:
    print(e)
# else:
#     print("everything is ok")

# %%
def  file(path,path2):
    try:
        with open(f"{path}",'r') as file1:
            with open(f"{path2}",'a') as file2:
                for i in file1:
                    file2.write(i)

            print("file found succesfully")
    except FileNotFoundError:
        print('file not found')
    else:
        print("ye to hona hi tha")


file("C:\\Users\\karli\\OneDrive\\Desktop\\all\\it_python\\advance\\e.txt","C:\\Users\\karli\\OneDrive\\Desktop\\all\\it_python\\advance\\t.txt")
# Out:
# file found succesfully
# ye to hona hi tha

# %%
file=open("t.txt")
file.readline()
# Out:
# 'python is the rision python is language \n'

# %%
file.readline()
# Out:
# ' and i love jave \n'

# %%
file.read()
# Out:
# ' i like dax\n'

# %%
file.seek(0)
# Out:
# 0

# %%
file=open('t.txt','w')
file.write('ONE',)
file.close()
