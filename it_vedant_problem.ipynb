# %%
#python problem 
#lhs=rhs

a=2
b=3

lhs= (a+b)**2
print(lhs)


rhs=a**2+2*a*b+b**2
print(rhs)

if lhs==rhs:
    print("equal")
else:
    print("not equal")
# Out:
# 25
# 25
# equal

# %% [markdown]
# Input:
# One number — temperature in Celsius (celsius)
#
# Process:
#
# Use the formula:
# fahrenheit = (celsius * 9/5) + 32
#
# Output:

# %%
cel=0


fah=(cel*9/5)+32

print(fah)
# Out:
# 32.0
